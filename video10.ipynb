# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/video10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list=[1,2,3,4]
list2=[4,3,2,1]
print(list+list2)
# Out:
# [1, 2, 3, 4, 4, 3, 2, 1]

# %%
list3=[3,True,"Turu",4.5]
print(list3[3]*8)
# Out:
# 36.0

# %%
list.append(9)
print(list)
# Out:
# [1, 2, 3, 4, 9]

# %%
print(list[4])
# Out:
# 9

# %%
print(len(list))
# Out:
# 5

# %%
l=[]
print(l)
# Out:
# []

# %%
print(l.append(90))
# Out:
# None

# %%
l.append(90)

# %%
print(l)
# Out:
# [90, 90]

# %%
l.append(90)
print(l.append(190))
# Out:
# None

# %%
print(l)
# Out:
# [90, 90, 90, 190]

# %%
t=(1,23,5,46,3)

# %%
print(t)
# Out:
# (1, 23, 5, 46, 3)

# %%
print(type(t))
# Out:
# <class 'tuple'>

# %%
t1=tuple(list)
print(t1)
# Out:
# (1, 2, 3, 4, 9)

# %%
s=set(list)

# %%
print(S)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3783/1150104196.py in <cell line: 0>()
# ----> 1 print(S)
#
# NameError: name 'S' is not defined

# %%
print(s)
# Out:
# {1, 2, 3, 4, 9}

# %%
l=[5,6,2,4,5,6,7,2,2,5,3]
print(l)
# Out:
# [5, 6, 2, 4, 5, 6, 7, 2, 2, 5, 3]

# %%
i1=tuple(l)
print(i1)
# Out:
# (5, 6, 2, 4, 5, 6, 7, 2, 2, 5, 3)

# %%
i2=set(l)
print(i2)
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
dict={1:"S",2:"H",3:"A",4:"A",5:"D"}
print(1)
# Out:
# 1

# %%
print(dict_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3783/3941024875.py in <cell line: 0>()
# ----> 1 print(dict_1)
#
# NameError: name 'dict_1' is not defined

# %%
print(dict[1])
# Out:
# S

# %%
print(dict[1]+dict[2]+dict[3]+dict[4]+dict[5])
# Out:
# SHAAD
