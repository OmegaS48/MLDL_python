# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/video11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=10
print(a!=b)
print(a==b)
# Out:
# True
# False

# %%
print(a>b)
print(b>a)
# Out:
# False
# True

# %%
(10 and 2)<3
# Out:
# True

# %%
2 or 3 >5
# Out:
# 2

# %%
(2 or 3)>5
# Out:
# False

# %%
not((5 and 6) >4)
# Out:
# False

# %%
3 is 3
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_888/30664588.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   3 is 3
# True

# %%
3 is not 4
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_888/3611417663.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   3 is not 4
# True

# %%
3 is not 3
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_888/3475991953.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   3 is not 3
# False

# %%
3 in [4,3,5,2]
# Out:
# True

# %%
30 in [3,32]
# Out:
# False

# %%
b=10
c=90
for i in range (90):
  print(b)
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
sp=44
sp1=[10,20,30,444]
print(sp not in sp1)
# Out:
# True
