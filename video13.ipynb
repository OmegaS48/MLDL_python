# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/video13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(3):
  a=int(input("Enter value : "))
  print(a)
# Out:
# Enter value : 12
# 12
# Enter value : 23
# 23
# Enter value : 44
# 44

# %%
s1=[12,24,36,48]
for i in range(4):
  print(s1[i]**2)
# Out:
# 144
# 576
# 1296
# 2304

# %%
i=0
while(i<4):
  print("Happy")
  i=i+1
# Out:
# Happy
# Happy
# Happy
# Happy

# %%
i=1
while(i<50):
  print(i)
  i=i*2
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %%
i=11
while(i<500):
  print(i)
  i=i+i
# Out:
# 11
# 22
# 44
# 88
# 176
# 352
