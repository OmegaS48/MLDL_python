# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/video48_vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set() #gives grids/themes to the plots

# %%
plt.quiver(0,0,1,1) #(xstart,ystart,anglewithx,anglewithy)
plt.show()

# %%
plt.quiver(0,0,45,80,scale_units='xy',angles='xy',scale=1,color='#FFDE21')
plt.xlim(-100,100)
plt.ylim(-100,100)
plt.show()

# %%
plt.quiver(0,0,45,80,scale_units='xy',angles='xy',scale=1,color='#FFDE21')
plt.quiver(0,0,-45,-40,scale_units='xy',angles='xy',scale=1,color='#FF34da')
plt.xlim(-100,100)
plt.ylim(-100,100)
plt.show()

# %%
v1=np.asarray([0,0,5,2])
v2=np.asarray([0,0,-3,1])
print(v1+v2)
# Out:
# [0 0 2 3]

# %%
plt.quiver(0,0,4,8,scale_units='xy',angles='xy',scale=1,color='#ffff12')
plt.quiver(4,8,5,10,scale_units='xy',angles='xy',scale=1,color='#ffddf1')

# %%
plt.quiver(0,0,40,80,scale_units='xy',angles='xy',scale=1,color='#ffff12')
plt.quiver(40,80,5,10,scale_units='xy',angles='xy',scale=1,color='r')
plt.xlim(-100,100)
plt.ylim(-100,100)
plt.show()

# %%
u=np.asarray([2,3])
v=np.asarray([-2,3])

# %%
u-v
# Out:
# array([4, 0])

# %%
plt.quiver(0,0,2,3,scale_units='xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,-2,3,scale_units='xy',angles='xy',scale=1,color='g')
plt.quiver(0,0,4,0,scale_units='xy',angles='xy',scale=1,color='y')
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.show()

# %%
plt.quiver(0,0,-2,3,scale_units='xy',angles='xy',scale=1,color='g')
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.show()

# %%
u=np.asarray([0,0,3,4])
a=-1*u

# %%
a
# Out:
# array([ 0,  0, -3, -4])

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,-3,-4,scale_units='xy',angles='xy',scale=1,color='r')
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.show()

# %%
import numpy as np

# %%
a=np.asarray([0,0,3,1])
b=np.asarray([0,0,5,2])

# %%
a*b
# Out:
# array([ 0,  0, 15,  2])

# %%
adotb=np.dot(a,b)

# %%
adotb
# Out:
# np.int64(17)

# %%
a1=np.asarray([3,4,5])
a2=np.asarray([1,4,5])
dotp=np.dot(a1,a2)

# %%
dotp
# Out:
# np.int64(44)

# %%
crossp=np.cross(a1,a2)
crossp
# Out:
# array([  0, -10,   8])

# %%
projection=np.dot(a1,a2)/np.sqrt(sum(a2**2))

# %%
projection
# Out:
# np.float64(6.789347398332044)

# %%
projection*a1
# Out:
# array([20.36804219, 27.15738959, 33.94673699])

# %%
projection*a2
# Out:
# array([ 6.7893474 , 27.15738959, 33.94673699])
