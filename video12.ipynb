# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/video12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if (30>50):
  print (99)
else:
  print (100)
# Out:
# 100

# %%
a=int(input("Enter 1 : "))
b=int(input("Enter 2 : "))
if(a>=b):
  print(a)
else:
  print(b)
# Out:
# Enter 1 : 90
# Enter 2 : 99
# 99

# %%
s="superman"
a=s[0]+s[1]+s[2]
if(a=="sup"):
  print (1)
elif(a=="super"):
  print(11)
else:
  print("??")
# Out:
# 1

# %%
a1=100
a2=900
a3=440
if(a1>a2 and a1>a3):
  print(a1)
elif(a2>a1 and a2>a3):
  print(a2)
elif(a3>a1 and a3>a2):
  print(a3)
# Out:
# 900

# %%
if(a2>a1):
  if(a2>a3):
    print("GREAT")
# Out:
# GREAT
