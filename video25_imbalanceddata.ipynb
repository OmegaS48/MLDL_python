# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/video25_imbalanceddata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
ccd=pd.read_csv('/content/credit_data.csv')

# %%
ccd.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
ccd.shape
# Out:
# (148636, 31)

# %% [markdown]
# 0 - legit transaction
# 1 - fraud

# %%
ccd['Class'].value_counts()
# Out:
# Class
# 0.0    148350
# 1.0       285
# Name: count, dtype: int64

# %%
legit=ccd[ccd.Class==0]
print(legit)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0           0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...       ...       ...       ...       ...       ...       ...       ...
# 148630  90089 -0.625582  0.829973  1.170429  0.048991  1.112722 -0.375808
# 148631  90089 -1.271847 -0.305529  1.050016 -0.229606  2.046442 -1.644978
# 148632  90090  0.009990  0.933721  0.376333 -0.402222  0.624493 -1.008371
# 148633  90091  1.942382 -0.522871 -0.218608  0.497250 -0.605545  0.216448
# 148634  90092  2.108337  0.303093 -1.778367  0.476308  0.860514 -0.413843
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
fraud=ccd[ccd.Class==1]
print(fraud)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 541       406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623       472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920     4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108     6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329     7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...       ...       ...       ...       ...       ...       ...       ...
# 144754  86376 -0.670238  0.945206  0.610051  2.640065 -2.707775  1.952611
# 145800  87202 -0.419820 -1.155978 -2.092516  2.786750  0.736297 -0.167292
# 146790  87883 -1.360293 -0.458069 -0.700404  2.737229 -1.005106  2.891399
# 147548  88672 -3.859881  2.632881 -5.264265  3.446113 -0.675231 -1.904959
# 147605  88737  1.917827  0.951967 -2.059206  3.833998  1.668192  0.769826
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
fraud.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
legit.shape
fraud.shape
# Out:
# (285, 31)

# %%
legit.shape
# Out:
# (148350, 31)

# %% [markdown]
# UnderSampling

# %%
#build a sample dataset mimicking this dataset's legit columns, keeping fraud the same
legitsample=legit.sample(n=285)

# %%
legitsample.shape
# Out:
# (285, 31)

# %%
ccd=pd.concat([legitsample,fraud],axis=0)

# %%
ccd
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 49232   43967 -0.254925  0.864102  0.973072  0.660145  0.496296 -0.257214
# 100609  67567  1.105644 -1.057353  1.028122 -0.470069 -1.422332  0.042268
# 36332   38491 -0.855821  0.731266  1.644628 -0.507700  1.142578  1.745453
# 86140   61098 -1.246566  0.534415 -0.295123 -2.088458  2.409146  2.978434
# 112452  72654 -1.116040  0.550557  1.999201 -0.730987  1.413172  0.628691
# ...       ...       ...       ...       ...       ...       ...       ...
# 144754  86376 -0.670238  0.945206  0.610051  2.640065 -2.707775  1.952611
# 145800  87202 -0.419820 -1.155978 -2.092516  2.786750  0.736297 -0.167292
# 146790  87883 -1.360293 -0.458069 -0.700404  2.737229 -1.005106  2.891399
# 147548  88672 -3.859881  2.632881 -5.264265  3.446113 -0.675231 -1.904959
# 147605  88737  1.917827  0.951967 -2.059206  3.833998  1.668192  0.769826
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
ccd.head()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 49232   43967 -0.254925  0.864102  0.973072  0.660145  0.496296 -0.257214
# 100609  67567  1.105644 -1.057353  1.028122 -0.470069 -1.422332  0.042268
# 36332   38491 -0.855821  0.731266  1.644628 -0.507700  1.142578  1.745453
# 86140   61098 -1.246566  0.534415 -0.295123 -2.088458  2.409146  2.978434
# 112452  72654 -1.116040  0.550557  1.999201 -0.730987  1.413172  0.628691
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 49232   1.052736 -0.249799 -0.218487  ...  0.020512  0.285603 -0.187431
# 100609 -0.994941  0.044381 -0.310970  ...  0.415901  1.127622 -0.184765
# 36332   0.509717  0.364685 -0.570406  ... -0.045234 -0.012500 -0.036601
# 86140   0.172959  1.249486 -0.993775  ... -0.428931 -1.888895  0.115688
# 112452  0.659579  0.256799 -0.536558  ... -0.119218 -0.220850 -0.019244
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
ccd.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 144754  86376 -0.670238  0.945206  0.610051  2.640065 -2.707775  1.952611
# 145800  87202 -0.419820 -1.155978 -2.092516  2.786750  0.736297 -0.167292
# 146790  87883 -1.360293 -0.458069 -0.700404  2.737229 -1.005106  2.891399
# 147548  88672 -3.859881  2.632881 -5.264265  3.446113 -0.675231 -1.904959
# 147605  88737  1.917827  0.951967 -2.059206  3.833998  1.668192  0.769826
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 144754 -1.624608 -5.229908  0.210202  ... -2.504450  1.436472  0.351542
# 145800  1.600027 -0.117427 -0.796954  ...  0.480640  0.533517  1.284645
# 146790  5.802537 -1.933197 -1.017717  ... -0.936990 -0.053812  0.580106
# 147548 -3.291041 -0.985766 -1.168114  ...  1.664119  0.785075  0.068412
# 147605  0.232463  0.107941 -1.143646  ...  0.015255  0.239994 -0.111916
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
ccd['Class'].value_counts()
# Out:
# Class
# 0.0    285
# 1.0    285
# Name: count, dtype: int64
