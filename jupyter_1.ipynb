# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/jupyter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print(98+10-9.8)
# Out:
# 98.2

# %%
for i in range(5):
  print("SuperMAN")
# Out:
# SuperMAN
# SuperMAN
# SuperMAN
# SuperMAN
# SuperMAN
