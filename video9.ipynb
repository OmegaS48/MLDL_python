# %% [markdown]
# <a href="https://colab.research.google.com/github/OmegaS48/MLDL_python/blob/main/video9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c=3+2j
d=2+3j
print(c+d)
# Out:
# (5+5j)

# %%
type(c+d)
# Out:
# complex

# %%
t=4.9
print(int(t))
# Out:
# 4

# %%
a=True
b=True
c=True
d=True
print(a+b+c+d)
# Out:
# 4

# %%
a=4<7
print(a)
# Out:
# True

# %%
b=4>90
print(b)
# Out:
# False

# %%
s1="Shaad"
s2="Ahmad"
print(s1+" "+s2)
# Out:
# Shaad Ahmad

# %%
print((s1+" \n")*44)
# Out:
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad
# Shaad

# %%
s3="Superman"

# %%
print(s3[0:8])
# Out:
# Superman

# %%
s="superman"
print(s[0:8:1])
# Out:
# superman

# %%
print(s[0:8:2])
# Out:
# spra

# %%
print(s[0:8:3])
# Out:
# sea

# %%
f="asdnuaspdfevcrnbmfhahun"
print(f[1:23:3])
# Out:
# superman
